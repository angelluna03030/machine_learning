# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_excel("datos_limpios.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Factura        49 non-null     object
#  1   Cliente        49 non-null     object
#  2   Ubicación      49 non-null     object
#  3   Genero         49 non-null     object
#  4   Producto       49 non-null     object
#  5   TipoVenta      49 non-null     object
#  6   Cantidad       49 non-null     int64
#  7   ValorUnitario  49 non-null     int64
#  8   SUBTOTAL       49 non-null     int64
# dtypes: int64(3), object(6)
# memory usage: 3.6+ KB

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.title("TipoVenta vs Producto")
plt.xlabel("TipoVenta")
plt.ylabel("Producto")
ax.bar(data["TipoVenta"], data["Producto"])
plt.show()

# %%
fig, ax = plt.subplots()
x = np.linspace(-3.0, 3.0, 100)
y = np.linspace(-3.0, 3.0, 100)
x, y = np.meshgrid(x, y)
z = np.sqrt(x**2 + 2*y**2)
ax.contourf(x, y, z)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.title("Genero vs Cantidad")
plt.xlabel("Cantidad")
plt.ylabel("Genero")
ax.scatter(data["Genero"], data["Cantidad"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 7
#       5 plt.xlabel("Cantidad")
#       6 plt.ylabel("Genero")
# ----> 7 ax.scatter(data["Genero"], data["Cantidad"])
#       8 plt.show()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Out:
# Ubicación
# Barbosa        175400
# Bello          108700
# Caldas         120800
# Copacabana     269400
# Envigado       496250
# Itagui         138900
# La estrella    233400
# Medellin       553800
# Name: SUBTOTAL, dtype: int64
# Genero
# Femenino      594400
# Masculino    1502250
# Name: SUBTOTAL, dtype: int64

# %%
df.to_excel('datos_limpios.xlsx', index=False)

# %%
profile = df.profile_report(title="Perfil de los Datos")
profile.to_file("Datos_con_subtotal.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\angel\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Pedro Fernández'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
